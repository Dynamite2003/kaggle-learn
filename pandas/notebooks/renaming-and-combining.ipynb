# %% [markdown]
# # Introduction
#
# Oftentimes data will come to us with column names, index names, or other naming conventions that we are not satisfied with. In that case, you'll learn how to use pandas functions to change the names of the offending entries to something better.
#
# You'll also explore how to combine data from multiple DataFrames and/or Series.
#
# **To start the exercise for this topic, please click [here](https://www.kaggle.com/kernels/fork/638064).**
#
# # Renaming
#
# The first function we'll introduce here is `rename()`, which lets you change index names and/or column names. For example, to change the `points` column in our dataset to `score`, we would do:

# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# `rename()` lets you rename index _or_ column values by specifying a `index` or `column` keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient. Here is an example using it to rename some elements of the index.

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#             region_1 region_2    taster_name taster_twitter_handle  \
# firstEntry      Etna      NaN  Kerin O’Keefe          @kerinokeefe
# secondEntry      NaN      NaN     Roger Voss            @vossroger
# ...              ...      ...            ...                   ...
# 129969        Alsace      NaN     Roger Voss            @vossroger
# 129970        Alsace      NaN     Roger Voss            @vossroger
#
#                                                          title  \
# firstEntry                   Nicosia 2013 Vulkà Bianco  (Etna)
# secondEntry      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                        ...
# 129969           Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970       Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                     variety                winery
# firstEntry      White Blend               Nicosia
# secondEntry  Portuguese Red   Quinta dos Avidagos
# ...                     ...                   ...
# 129969           Pinot Gris  Domaine Marcel Deiss
# 129970       Gewürztraminer      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely.  For that, `set_index()` is usually more convenient.
#
# Both the row index and the column index can have their own `name` attribute. The complimentary `rename_axis()` method may be used to change these names. For example:

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
# fields                                              title         variety  \
# wines
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
# fields                winery
# wines
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# # Combining
#
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are `concat()`, `join()`, and `merge()`. Most of what `merge()` can do can also be done more simply with `join()`, so we will omit it and focus on the first two functions here.
#
# The simplest combining method is `concat()`. Given a list of elements, this function will smush those elements together along an axis.
#
# This is useful when we have data in different DataFrame or Series objects but having the same fields (columns). One example: the [YouTube Videos dataset](https://www.kaggle.com/datasnaek/youtube-new), which splits the data up based on country of origin (e.g. Canada and the UK, in this example). If we want to study multiple countries simultaneously, we can use `concat()` to smush them together:

# %%
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 10591  p9RLCdyn_40      18.05.01
# 10592  ifkRhaEDzzo      18.05.01
#
#                                                  title       channel_title  \
# 0           Eminem - Walk On Water (Audio) ft. Beyoncé          EminemVEVO
# 1                        PLUSH - Bad Unboxing Fan Mail           iDubbbzTV
# ...                                                ...                 ...
# 10591  ACCIDENTAL RING SHOPPING & PARTY TIME | VLOGMAS          MoreZoella
# 10592         TRYING ON ENGAGEMENT RINGS (no proposal)  PointlessBlogVlogs
#
#        category_id              publish_time  \
# 0               10  2017-11-10T17:00:03.000Z
# 1               23  2017-11-13T17:00:00.000Z
# ...            ...                       ...
# 10591           22  2017-12-16T16:00:07.000Z
# 10592           24  2017-12-16T17:00:08.000Z
#
#                                                     tags     views   likes  \
# 0      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1      plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
# ...                                                  ...       ...     ...
# 10591  zoe sugg|"zoella"|"zoe"|"vlog"|"vlogging"|"vlo...   1070142   55662
# 10592  pointlessblog|"pointlessblogtv"|"pointlessblog...    538885   28171
#
#        dislikes  comment_count  \
# 0         43420         125882
# 1          1688          13030
# ...         ...            ...
# 10591       540            344
# 10592       768            276
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 1      https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg              False
# ...                                               ...                ...
# 10591  https://i.ytimg.com/vi/p9RLCdyn_40/default.jpg              False
# 10592  https://i.ytimg.com/vi/ifkRhaEDzzo/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# ...                 ...                     ...
# 10591             False                   False
# 10592             False                   False
#
#                                              description
# 0      Eminem's new track Walk on Water ft. Beyoncé i...
# 1      STill got a lot of packages. Probably will las...
# ...                                                  ...
# 10591  ACCIDENTAL RING SHOPPING & PARTY TIME\n❄ Vlogm...
# 10592  ► TRYING ON ENGAGEMENT RINGS\n► 20% Off PB Mer...
#
# [21185 rows x 16 columns]

# %% [markdown]
# The middlemost combiner in terms of complexity is `join()`. `join()` lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in _both_ Canada and the UK, we could do the following:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# ...                                                                       ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01       lIGn7Ii0cCU
# Thank You To The Viewers! (Music Video)            18.05.01       TPtWYfdW6Gc
#
#                                                                  channel_title_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11             EminemVEVO
# PLUSH - Bad Unboxing Fan Mail                      17.14.11              iDubbbzTV
# ...                                                                            ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01          Freegate News
# Thank You To The Viewers! (Music Video)            18.05.01                  Smosh
#
#                                                                   category_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                    10
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                    23
# ...                                                                           ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                    25
# Thank You To The Viewers! (Music Video)            18.05.01                    23
#
#                                                                           publish_time_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       2017-11-10T17:00:03.000Z
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       2017-11-13T17:00:00.000Z
# ...                                                                                    ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01       2018-01-03T23:44:44.000Z
# Thank You To The Viewers! (Music Video)            18.05.01       2018-01-03T17:00:03.000Z
#
#                                                                                                            tags_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       plush|"bad unboxing"|"unboxing"|"fan mail"|"id...
# ...                                                                                                             ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                                                playlist
# Thank You To The Viewers! (Music Video)            18.05.01       smosh|"musical"|"smosh musical"|"smosh music v...
#
#                                                                   views_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11        17158579
# PLUSH - Bad Unboxing Fan Mail                      17.14.11         1014651
# ...                                                                     ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01          142234
# Thank You To The Viewers! (Music Video)            18.05.01          296922
#
#                                                                   likes_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11          787425
# PLUSH - Bad Unboxing Fan Mail                      17.14.11          127794
# ...                                                                     ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01            1386
# Thank You To The Viewers! (Music Video)            18.05.01           26686
#
#                                                                   dislikes_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11              43420
# PLUSH - Bad Unboxing Fan Mail                      17.14.11               1688
# ...                                                                        ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                181
# Thank You To The Viewers! (Music Video)            18.05.01                602
#
#                                                                   comment_count_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                  125882
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                   13030
# ...                                                                             ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                     476
# Thank You To The Viewers! (Music Video)            18.05.01                    3397
#
#                                                                                               thumbnail_link_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# ...                                                                                                          ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01       https://i.ytimg.com/vi/lIGn7Ii0cCU/default.jpg
# Thank You To The Viewers! (Music Video)            18.05.01       https://i.ytimg.com/vi/TPtWYfdW6Gc/default.jpg
#
#                                                                   ...  \
# title                                              trending_date  ...
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       ...
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       ...
# ...                                                               ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01       ...
# Thank You To The Viewers! (Music Video)            18.05.01       ...
#
#                                                                                                             tags_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                                                     NaN
# ...                                                                                                             ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                                                     NaN
# Thank You To The Viewers! (Music Video)            18.05.01                                                     NaN
#
#                                                                     views_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       17158579.0
# PLUSH - Bad Unboxing Fan Mail                      17.14.11              NaN
# ...                                                                      ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01              NaN
# Thank You To The Viewers! (Music Video)            18.05.01              NaN
#
#                                                                   likes_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       787420.0
# PLUSH - Bad Unboxing Fan Mail                      17.14.11            NaN
# ...                                                                    ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01            NaN
# Thank You To The Viewers! (Music Video)            18.05.01            NaN
#
#                                                                  dislikes_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11          43420.0
# PLUSH - Bad Unboxing Fan Mail                      17.14.11              NaN
# ...                                                                      ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01              NaN
# Thank You To The Viewers! (Music Video)            18.05.01              NaN
#
#                                                                  comment_count_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11              125882.0
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                   NaN
# ...                                                                           ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                   NaN
# Thank You To The Viewers! (Music Video)            18.05.01                   NaN
#
#                                                                                                thumbnail_link_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                                                  NaN
# ...                                                                                                          ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                                                  NaN
# Thank You To The Viewers! (Music Video)            18.05.01                                                  NaN
#
#                                                                   comments_disabled_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                      False
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                        NaN
# ...                                                                                ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                        NaN
# Thank You To The Viewers! (Music Video)            18.05.01                        NaN
#
#                                                                  ratings_disabled_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                    False
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                      NaN
# ...                                                                              ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                      NaN
# Thank You To The Viewers! (Music Video)            18.05.01                      NaN
#
#                                                                  video_error_or_removed_UK  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                          False
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                            NaN
# ...                                                                                    ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                            NaN
# Thank You To The Viewers! (Music Video)            18.05.01                            NaN
#
#                                                                                                      description_UK
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem's new track Walk on Water ft. Beyoncé i...
# PLUSH - Bad Unboxing Fan Mail                      17.14.11                                                     NaN
# ...                                                                                                             ...
# علی جوانمردی: خامنه‌ای خانواده‌اش را به ترکیه ف... 18.05.01                                                     NaN
# Thank You To The Viewers! (Music Video)            18.05.01                                                     NaN
#
# [10592 rows x 28 columns]

# %% [markdown]
# The `lsuffix` and `rsuffix` parameters are necessary here because the data has the same column names in both British and Canadian datasets. If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.
#
# # Your turn
#
# If you haven't started the exercise, you can **[get started here](https://www.kaggle.com/kernels/fork/638064)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
